# %%
#Import deps 
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold


from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.over_sampling import SMOTENC

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %% [markdown]
# ### Dataset

# %%
path = os.getcwd()
data = 'Resources\\Wine_data_both.csv'
path = path.replace('all_wine_raw',data)

df = pd.read_csv(path)

# %% [markdown]
# ### <font color='blue'>Exploratory analysis<font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  Wine                  6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Wine                    0
# dtype: int64

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality   Wine
# 0      8.8        6  White
# 1      9.5        6  White
# 2     10.1        6  White
# 3      9.9        6  White
# 4      9.9        6  White

# %% [markdown]
# #### Casting as category type

# %%
df['quality'] = df['quality'].astype('category')
df['Wine'] = df['Wine'].astype('category')

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol
# count  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801
# std       0.160787     0.148806     1.192712
# min       2.720000     0.220000     8.000000
# 25%       3.110000     0.430000     9.500000
# 50%       3.210000     0.510000    10.300000
# 75%       3.320000     0.600000    11.300000
# max       4.010000     2.000000    14.900000

# %% [markdown]
# #### Feature distribution  Viz

# %%
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Note:**
#         The scale for 'total sulfur dioxide' and 'free sulfur dioxided' measurments are significantly bigger than the rest<br>
#         of the features

# %% [markdown]
# #### Correlation

# %%
X_df = df.drop(columns = ['Wine','quality'])

X_corr = X_df.corr().round(1)

sns.heatmap(X_corr,annot=True,cmap='flare') 
plt.show()

# %% [markdown]
# **Note:**
#             free sulfur dioxide and total sulfur dioxide have a significant positive correlation<br>
#             alcohol and density have a significant negative correlation.

# %% [markdown]
# #### Target : Wine type

# %%
sns.set_style(rc = {'axes.facecolor': 'darkgrey'})
sns.countplot(
               x = df['Wine'],
               hue = df['Wine'],
               palette=['white',"red"]).set(title='Wine type'
              )
plt.show()

# %%
df['Wine'].value_counts()
# Out:
# Wine
# White    4898
# Red      1599
# Name: count, dtype: int64

# %% [markdown]
# **Note:**
#     The target variable is heavily inbalanced 3 'White' to 1 'Red'

# %% [markdown]
# #### Target: Quality

# %%
sns.countplot(x = df['quality']).set(title='Wine quality')
plt.show()

# %%
df['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# #### Quality count by wine type

# %%
sns.set_style(rc = {'axes.facecolor': 'darkgrey'})
sns.countplot( x = df['quality'],
               hue = df['Wine'], 
               palette=['white',"red"]).set(title='Quality count by Wine Type ')
plt.show()

# %% [markdown]
# ### Reclassifying target

# %%
df['quality'] = df['quality'].replace([3,4,5],'low')
df['quality'] = df['quality'].replace([6],'medium')
df['quality'] = df['quality'].replace([7,8,9],'high')


df['quality'] = df['quality'].astype('category')

# %% [markdown]
# ### Reclassified Viz

# %%
sns.set_style(rc = {'axes.facecolor': 'darkgrey'})
sns.countplot(
               x = df['quality'],
               hue = df['Wine'], 
               palette=['white',"red"]).set(title='Quality count by Wine Type ')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Splitting and encoding features

# %%
X = df.drop(columns = ['Wine','quality',])
y = df['quality']

le = LabelEncoder()
le.fit(y)

y = le.transform(y)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Building Models

# %% [markdown]
# #### Splitting data

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %% [markdown]
# ---

# %% [markdown]
# #### KNeighborsClassifier

# %%
train_scores = []
test_scores = []
for n in range(1,10):
    knc = KNeighborsClassifier(n_neighbors = n)
    knc.fit(X_train,y_train)
    train_scores.append(knc.score(X_train,y_train))
    test_scores.append(knc.score(X_test,y_test))

# %%
plt.plot([*range(1,10)],train_scores)
plt.plot([*range(1,10)],test_scores)
plt.show()

# %% [markdown]
# #### Model fit

# %%
knc = KNeighborsClassifier(n_neighbors = 1 )
knc.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = knc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51       308
#            1       0.63      0.65      0.64       583
#            2       0.63      0.62      0.63       734
#
#     accuracy                           0.61      1625
#    macro avg       0.59      0.59      0.59      1625
# weighted avg       0.61      0.61      0.61      1625

# %% [markdown]
# ---

# %% [markdown]
# #### SVC

# %%
param_grid_svc = {
              'C': [5,10,15], 
              'gamma': [1,2,3,4],
              'kernel': ['rbf']
              }
grid_svc= GridSearchCV(
                       SVC(),
                       param_grid_svc,
                       refit=True,verbose=3
                       )

grid_svc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.590 total time=   5.9s
# [CV 2/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.591 total time=   6.0s
# [CV 3/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.586 total time=   5.7s
# [CV 4/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.562 total time=   5.7s
# [CV 5/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.582 total time=   5.7s
# [CV 1/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.575 total time=   5.8s
# [CV 2/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.587 total time=   5.8s
# [CV 3/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.577 total time=   5.8s
# [CV 4/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.563 total time=   5.8s
# [CV 5/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.580 total time=   5.8s
# [CV 1/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.573 total time=   5.9s
# [CV 2/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.584 total time=   5.9s
# [CV 3/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.571 total time=   5.8s
# [CV 4/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.563 total time=   5.9s
# [CV 5/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.571 total time=   6.0s
# [CV 1/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.570 total time=   6.1s
# [CV 2/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.584 total time=   6.0s
# [CV 3/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.570 total time=   6.1s
# [CV 4/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.560 total time=   5.8s
# [CV 5/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.573 total time=   5.8s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.589 total time=   5.6s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.591 total time=   5.9s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.585 total time=   5.7s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.562 total time=   5.6s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.582 total time=   5.7s
# [CV 1/5] END .........C=10, gamma=2, kernel=rbf;, score=0.575 total time=   5.7s
# [CV 2/5] END .........C=10, gamma=2, kernel=rbf;, score=0.587 total time=   5.8s
# [CV 3/5] END .........C=10, gamma=2, kernel=rbf;, score=0.577 total time=   5.7s
# [CV 4/5] END .........C=10, gamma=2, kernel=rbf;, score=0.563 total time=   5.8s
# [CV 5/5] END .........C=10, gamma=2, kernel=rbf;, score=0.580 total time=   5.7s
# [CV 1/5] END .........C=10, gamma=3, kernel=rbf;, score=0.573 total time=   5.8s
# [CV 2/5] END .........C=10, gamma=3, kernel=rbf;, score=0.584 total time=   5.7s
# [CV 3/5] END .........C=10, gamma=3, kernel=rbf;, score=0.571 total time=   5.8s
# [CV 4/5] END .........C=10, gamma=3, kernel=rbf;, score=0.563 total time=   5.7s
# [CV 5/5] END .........C=10, gamma=3, kernel=rbf;, score=0.571 total time=   5.8s
# [CV 1/5] END .........C=10, gamma=4, kernel=rbf;, score=0.570 total time=   5.8s
# [CV 2/5] END .........C=10, gamma=4, kernel=rbf;, score=0.584 total time=   5.7s
# [CV 3/5] END .........C=10, gamma=4, kernel=rbf;, score=0.570 total time=   5.8s
# [CV 4/5] END .........C=10, gamma=4, kernel=rbf;, score=0.560 total time=   5.8s
# [CV 5/5] END .........C=10, gamma=4, kernel=rbf;, score=0.573 total time=   5.7s
# [CV 1/5] END .........C=15, gamma=1, kernel=rbf;, score=0.589 total time=   5.6s
# [CV 2/5] END .........C=15, gamma=1, kernel=rbf;, score=0.591 total time=   5.6s
# [CV 3/5] END .........C=15, gamma=1, kernel=rbf;, score=0.585 total time=   5.6s
# [CV 4/5] END .........C=15, gamma=1, kernel=rbf;, score=0.562 total time=   5.6s
# [CV 5/5] END .........C=15, gamma=1, kernel=rbf;, score=0.582 total time=   5.6s
# [CV 1/5] END .........C=15, gamma=2, kernel=rbf;, score=0.575 total time=   5.7s
# [CV 2/5] END .........C=15, gamma=2, kernel=rbf;, score=0.587 total time=   5.7s
# [CV 3/5] END .........C=15, gamma=2, kernel=rbf;, score=0.577 total time=   5.7s
# [CV 4/5] END .........C=15, gamma=2, kernel=rbf;, score=0.563 total time=   5.7s
# [CV 5/5] END .........C=15, gamma=2, kernel=rbf;, score=0.580 total time=   5.7s
# [CV 1/5] END .........C=15, gamma=3, kernel=rbf;, score=0.573 total time=   5.8s
# [CV 2/5] END .........C=15, gamma=3, kernel=rbf;, score=0.584 total time=   3.1s
# [CV 3/5] END .........C=15, gamma=3, kernel=rbf;, score=0.571 total time=   2.5s
# [CV 4/5] END .........C=15, gamma=3, kernel=rbf;, score=0.563 total time=   2.3s
# [CV 5/5] END .........C=15, gamma=3, kernel=rbf;, score=0.571 total time=   1.7s
# [CV 1/5] END .........C=15, gamma=4, kernel=rbf;, score=0.570 total time=   2.1s
# [CV 2/5] END .........C=15, gamma=4, kernel=rbf;, score=0.584 total time=   2.2s
# [CV 3/5] END .........C=15, gamma=4, kernel=rbf;, score=0.570 total time=   2.0s
# [CV 4/5] END .........C=15, gamma=4, kernel=rbf;, score=0.560 total time=   2.3s
# [CV 5/5] END .........C=15, gamma=4, kernel=rbf;, score=0.573 total time=   2.3s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [5, 10, 15], 'gamma': [1, 2, 3, 4],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid_svc.best_params_)
print(grid_svc.best_score_)
# Out:
# {'C': 5, 'gamma': 1, 'kernel': 'rbf'}
# 0.5820984573263834

# %% [markdown]
# #### Model fit

# %%
C = grid_svc.best_params_['C'] 
gamma = grid_svc.best_params_['gamma']
kernel = grid_svc.best_params_['kernel']
                              
svc = SVC(C = C,
         gamma = gamma,
         kernel = kernel)

svc.fit(X_train,y_train)
# Out:
# SVC(C=5, gamma=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = svc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.31      0.46       308
#            1       0.78      0.38      0.51       583
#            2       0.55      0.92      0.68       734
#
#     accuracy                           0.61      1625
#    macro avg       0.74      0.54      0.55      1625
# weighted avg       0.70      0.61      0.58      1625

# %% [markdown]
# ---

# %% [markdown]
# #### DecisionTreeClassifier

# %%
param_grid_dtc = { 
                  'criterion': ['gini', 'entropy', 'log_loss'], 
                  'splitter': ['best','random'],
                  'max_features': ['sqrt', 'log2'],
                  'max_depth': [10,20, 30], 
                  'max_leaf_nodes': [900,1000,1100],
                  'min_samples_split': [4,6,8], 
                    } 

grid_dtc = GridSearchCV(
                        DecisionTreeClassifier(),
                        param_grid_dtc,
                        refit=True,verbose=3
                       )

grid_dtc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0
best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc.best_params_['min_samples_split']
    
                            )

dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        max_leaf_nodes=900, min_samples_split=4)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = dtc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57       308
#            1       0.64      0.69      0.66       583
#            2       0.62      0.56      0.59       734
#
#     accuracy                           0.61      1625
#    macro avg       0.60      0.62      0.61      1625
# weighted avg       0.61      0.61      0.61      1625

# %% [markdown]
# ---

# %% [markdown]
# #### RandomForestClassifier

# %%
param_grid_rfc = { 
                 'n_estimators': [200, 215,220], 
                 'max_features': ['sqrt', 'log2', None], 
                 'max_depth': [10,20, 30], 
                 'max_leaf_nodes': [900,1000,1100],
                 'min_samples_split': [4,6,8], 
                 } 

grid_rfc = GridSearchCV(
                        RandomForestClassifier(),
                        param_grid_rfc,
                        refit=True,verbose=3
                       )

grid_rfc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.655 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.691 total time=   1.3s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.661 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.662 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.658 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.648 total time=   2.1s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.692 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.671 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.670 total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.664 total time=   1.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.650 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.690 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.667 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.665 total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.652 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.650 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.679 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.672 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.666 total time=   1.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.651 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.644 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.695 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.667 total time=   2.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.672 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.659 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.653 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.687 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.662 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.663 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.660 total time=   2.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.637 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.679 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.661 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.664 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.656 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.649 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.690 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.660 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.660 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.653 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.639 total time=   1.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.688 total time=   2.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.664 total time=   2.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.666 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.658 total time=   1.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.646 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.692 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.669 total time=   1.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.670 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.663 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.637 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.692 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.665 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.669 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.658 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.651 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.705 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.669 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.671 total time=   1.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.661 total time=   1.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.643 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.694 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.669 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.674 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.657 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.647 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.681 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.674 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.666 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.666 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.657 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.688 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.662 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.659 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.657 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.641 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.678 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.656 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.670 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.655 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.647 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.693 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.662 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.670 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.658 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.644 total time=   1.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.690 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.657 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.665 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.658 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.636 total time=   1.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.688 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.665 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.663 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.668 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.651 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.683 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.662 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.674 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.651 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.646 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.694 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.670 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.670 total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.666 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.650 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.695 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.663 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.668 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.663 total time=   1.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.646 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.695 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.656 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.668 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.666 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.648 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.689 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.651 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.671 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.660 total time=   1.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.646 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.686 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.660 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.667 total time=   1.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.656 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.647 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.686 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.661 total time=   1.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.666 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.652 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.645 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.689 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.656 total time=   1.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.669 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.643 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.645 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.689 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.665 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.679 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.658 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.653 total time=   2.0s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.689 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.674 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.672 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.656 total time=   1.8s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.652 total time=   2.0s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.692 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.661 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.671 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.659 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.646 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.689 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.661 total time=   1.8s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.663 total time=   1.4s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.652 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.646 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.691 total time=   1.9s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.661 total time=   1.8s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.668 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.649 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.635 total time=   1.8s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.676 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.667 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.676 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.663 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.640 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.688 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.660 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.681 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.661 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.642 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.683 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.659 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.668 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.664 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.645 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.684 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.660 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.660 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.662 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.644 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.695 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.670 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.663 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.666 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.648 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.693 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.674 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.669 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.665 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.644 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.692 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.660 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.666 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.654 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.638 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.683 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.663 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.665 total time=   1.4s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.661 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.655 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.692 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.666 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.666 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.661 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.645 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.689 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.662 total time=   1.8s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.666 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.658 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.633 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.672 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.661 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.667 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.656 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.640 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.677 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.660 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.659 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.653 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.647 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.688 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.652 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.662 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.653 total time=   2.1s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.652 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.693 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.668 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.665 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.664 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.648 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.701 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.668 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.666 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.664 total time=   1.5s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.655 total time=   1.8s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.694 total time=   1.7s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.663 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.682 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.662 total time=   2.0s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.648 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.685 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.674 total time=   1.4s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.666 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.664 total time=   1.6s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.644 total time=   1.7s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.690 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.662 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.674 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.663 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.643 total time=   1.6s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.692 total time=   1.8s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.669 total time=   1.9s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.666 total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.660 total time=   1.7s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.639 total time=   1.4s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.687 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.666 total time=   1.5s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.662 total time=   1.6s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.652 total time=   1.4s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.649 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.686 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.662 total time=   1.6s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.676 total time=   1.8s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.656 total time=   1.8s
# [CV 1/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.647 total time=   1.8s
# [CV 2/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.689 total time=   1.5s
# [CV 3/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.658 total time=   1.8s
# [CV 4/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.665 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.659 total time=   1.9s
# [CV 1/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.653 total time=   4.7s
# [CV 2/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.676 total time=   4.6s
# [CV 3/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.681 total time=   4.5s
# [CV 4/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.670 total time=   4.3s
# [CV 5/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.664 total time=   4.2s
# [CV 1/5] END max_depth=10, max_features=None, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0
8s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.679 total time=   6.5s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.710 total time=   6.2s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.727 total time=   6.0s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.687 total time=   6.2s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.683 total time=   6.4s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.675 total time=   6.3s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.710 total time=   6.4s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.719 total time=   6.8s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.688 total time=   6.2s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.681 total time=   6.4s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.682 total time=   5.7s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.701 total time=   5.6s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.717 total time=   5.9s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.686 total time=   5.9s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.686 total time=   5.6s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.676 total time=   6.5s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.706 total time=   6.7s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.714 total time=   5.8s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.688 total time=   6.1s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.686 total time=   5.9s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.670 total time=   5.7s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.703 total time=   5.6s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.706 total time=   6.0s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.682 total time=   5.6s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.689 total time=   5.7s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.678 total time=   5.3s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.712 total time=   5.4s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.717 total time=   6.0s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.684 total time=   5.3s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.684 total time=   5.0s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.670 total time=   5.5s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.712 total time=   5.6s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.717 total time=   5.7s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.681 total time=   5.4s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.689 total time=   5.5s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.670 total time=   6.1s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.707 total time=   5.5s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.703 total time=   5.7s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.676 total time=   6.1s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.693 total time=   5.7s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [900, 1000, 1100],
#                          'min_samples_split': [4, 6, 8],
#                          'n_estimators': [200, 215, 220]},
#              verbose=3)

# %%
print(grid_rfc.best_params_)
print(grid_rfc.best_score_)
# Out:
# {'max_depth': 30, 'max_features': 'log2', 'max_leaf_nodes': 1000, 'min_samples_split': 4, 'n_estimators': 200}
# 0.7068962249249722

# %% [markdown]
# #### Model fit

# %%
rfc = RandomForestClassifier( 
                             n_estimators = grid_rfc.best_params_['n_estimators'], 
                             max_features =  grid_rfc.best_params_['max_features'],
                             max_depth =  grid_rfc.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc.best_params_['max_leaf_nodes'],
                        
                            )

rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=30, max_features='log2', max_leaf_nodes=1000,
#                        n_estimators=200)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.57      0.65       308
#            1       0.74      0.78      0.76       583
#            2       0.69      0.73      0.71       734
#
#     accuracy                           0.72      1625
#    macro avg       0.73      0.69      0.71      1625
# weighted avg       0.72      0.72      0.71      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier (estimator = DecisionTreeClassifier)

# %%
param_grid_abc_dt = { 
                     'n_estimators': [210,212,215,],
                     'learning_rate':[0.5,0.75,1]
                    }

dtc = DecisionTreeClassifier( 
                             criterion =grid_dtc.best_params_['criterion'],
                             splitter = grid_dtc.best_params_['splitter'],
                             max_features =  grid_dtc.best_params_['max_features'],
                             max_depth =  grid_dtc.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc.best_params_['min_samples_split']
    
                            )


abc_dt = AdaBoostClassifier(estimator = dtc)

grid_abc_dt= GridSearchCV(
                          abc_dt,
                          param_grid_abc_dt,
                          refit=True,verbose=3
                          )

grid_abc_dt.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.677 total time=   4.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.715 total time=   3.9s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.707 total time=   4.2s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.695 total time=   4.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.697 total time=   4.4s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.677 total time=   4.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.719 total time=   4.1s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.711 total time=   4.3s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.700 total time=   4.2s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.688 total time=   4.7s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.672 total time=   4.3s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.714 total time=   4.7s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.707 total time=   4.1s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.696 total time=   4.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.689 total time=   4.3s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.677 total time=   4.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.724 total time=   4.3s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.708 total time=   4.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.689 total time=   4.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.691 total time=   4.0s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.683 total time=   4.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.717 total time=   4.0s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.718 total time=   4.2s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.689 total time=   4.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.698 total time=   4.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.677 total time=   4.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.720 total time=   4.2s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.710 total time=   4.2s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.700 total time=   4.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.705 total time=   4.2s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.677 total time=   4.1s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.725 total time=   4.1s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.714 total time=   4.2s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.697 total time=   3.9s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.703 total time=   4.2s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.671 total time=   4.1s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.733 total time=   4.2s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.700 total time=   4.3s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.693 total time=   4.1s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.700 total time=   3.9s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.670 total time=   4.2s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.721 total time=   4.1s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.702 total time=   4.2s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.703 total time=   4.0s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.699 total time=   4.1s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                            max_depth=30,
#                                                                            max_features='sqrt',
#                                                                            max_leaf_nodes=900,
#                                                                            min_samples_split=4)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_dt.best_params_)
print(grid_abc_dt.best_score_)
# Out:
# {'learning_rate': 1, 'n_estimators': 210}
# 0.7032028642131312

# %% [markdown]
# #### Model fit

# %%
dtc = DecisionTreeClassifier( 
                             criterion =grid_dtc.best_params_['criterion'],
                             splitter = grid_dtc.best_params_['splitter'],
                             max_features =  grid_dtc.best_params_['max_features'],
                             max_depth =  grid_dtc.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc.best_params_['min_samples_split']
    
                            )

abc_dt = AdaBoostClassifier(
                        estimator = dtc,
                        n_estimators = grid_abc_dt.best_params_['n_estimators'],
                        learning_rate= grid_abc_dt.best_params_['learning_rate']
                        )

abc_dt.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                     max_depth=30,
#                                                     max_features='sqrt',
#                                                     max_leaf_nodes=900,
#                                                     min_samples_split=4),
#                    learning_rate=1, n_estimators=210)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = abc_dt.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.55      0.66       308
#            1       0.78      0.77      0.78       583
#            2       0.69      0.79      0.74       734
#
#     accuracy                           0.74      1625
#    macro avg       0.76      0.70      0.72      1625
# weighted avg       0.75      0.74      0.74      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier (estimator = RandomForestClassifier)

# %%
param_grid_abc_rfc = { 
                      'n_estimators': [210,212,215,],
                      'learning_rate':[0.5,0.75,1]
                     }

rfc = RandomForestClassifier( 
                             n_estimators = grid_rfc.best_params_['n_estimators'], 
                             max_features =  grid_rfc.best_params_['max_features'],
                             max_depth =  grid_rfc.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc.best_params_['max_leaf_nodes'],
                             
                            )

abc_rfc = AdaBoostClassifier(estimator = rfc)

grid_abc_rfc = GridSearchCV(
                           abc_rfc,
                           param_grid_abc_rfc,
                           refit=True,verbose=3
                           )

grid_abc_rfc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.683 total time=   2.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.720 total time=   2.2s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.727 total time=   2.2s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.688 total time=   2.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.699 total time=   2.3s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.682 total time=   2.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.726 total time=   2.3s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.719 total time=   2.5s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.694 total time=   2.5s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.711 total time=   2.5s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.681 total time=   2.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.730 total time=   2.4s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.715 total time=   2.3s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.696 total time=   2.1s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.690 total time=   2.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.688 total time=   2.4s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.724 total time=   2.4s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.719 total time=   2.2s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.683 total time=   2.1s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.699 total time=   2.2s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.683 total time=   2.2s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.726 total time=   2.6s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.723 total time=   2.2s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.690 total time=   2.2s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.703 total time=   2.0s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.681 total time=   2.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.725 total time=   2.3s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.705 total time=   2.2s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.699 total time=   2.1s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.697 total time=   2.1s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.678 total time=   2.1s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.725 total time=   2.2s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.707 total time=   2.2s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.688 total time=   2.1s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.703 total time=   2.1s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.685 total time=   2.2s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.728 total time=   2.2s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.711 total time=   2.1s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.691 total time=   2.5s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.697 total time=   2.4s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.679 total time=   2.5s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.728 total time=   2.2s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.714 total time=   2.8s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.694 total time=   2.3s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.708 total time=   2.4s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=RandomForestClassifier(max_depth=30,
#                                                                            max_features='log2',
#                                                                            max_leaf_nodes=1000,
#                                                                            n_estimators=200)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_rfc.best_params_)
print(grid_abc_rfc.best_score_)
# Out:
# {'learning_rate': 0.5, 'n_estimators': 212}
# 0.7064870215342494

# %% [markdown]
# #### Model Fit

# %%
rfc = RandomForestClassifier( 
                             n_estimators = grid_rfc.best_params_['n_estimators'], 
                             max_features =  grid_rfc.best_params_['max_features'],
                             max_depth =  grid_rfc.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc.best_params_['max_leaf_nodes'],
                             
    
                            )

abc_rfc = AdaBoostClassifier(
                             estimator = rfc,
                             n_estimators = grid_abc_rfc.best_params_['n_estimators'],
                             learning_rate= grid_abc_rfc.best_params_['learning_rate']
                            )

abc_rfc.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(max_depth=30,
#                                                     max_features='log2',
#                                                     max_leaf_nodes=1000,
#                                                     n_estimators=200),
#                    learning_rate=0.5, n_estimators=212)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = abc_rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.58      0.66       308
#            1       0.75      0.75      0.75       583
#            2       0.68      0.75      0.71       734
#
#     accuracy                           0.72      1625
#    macro avg       0.73      0.70      0.71      1625
# weighted avg       0.72      0.72      0.72      1625

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Scaled

# %% [markdown]
# #### Scaling Data

# %%
scaler = StandardScaler()
X = df.drop(columns = ['Wine','quality'])
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Feature distribution  Viz

# %%
cols = df.drop(columns=['Wine','quality']).columns

X_df = pd.DataFrame(X_scaled,columns = cols)
X_df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Scaling Data

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---

# %% [markdown]
# #### KNeighborsClassifier

# %%
train_scores_scaled = []
test_scores_scaled = []
for n in range(1,10):
    knc_scaled = KNeighborsClassifier(n_neighbors = n)
    knc_scaled.fit(
            X_train_scaled,
            y_train
           )
    train_scores_scaled.append(knc_scaled.score(X_train_scaled,y_train))
    test_scores_scaled.append(knc_scaled.score(X_test_scaled,y_test))

# %%
plt.plot([*range(1,10)],train_scores_scaled)
plt.plot([*range(1,10)],test_scores_scaled)
plt.show()

# %% [markdown]
# #### Model fit

# %%
knc_scaled = KNeighborsClassifier(n_neighbors = 1 )
knc_scaled.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = knc_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64       308
#            1       0.68      0.70      0.69       583
#            2       0.67      0.63      0.65       734
#
#     accuracy                           0.66      1625
#    macro avg       0.65      0.67      0.66      1625
# weighted avg       0.66      0.66      0.66      1625

# %% [markdown]
# ---

# %% [markdown]
# #### SVC

# %%
param_grid_svc_scaled = {
              'C': [5,10,15], 
              'gamma': [1,2,3,4],
              'kernel': ['rbf']
              }
grid_svc_scaled= GridSearchCV(
                              SVC(),
                              param_grid_svc_scaled,
                              refit=True,verbose=3
                             )

grid_svc_scaled.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.639 total time=   1.4s
# [CV 2/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.678 total time=   1.5s
# [CV 3/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.654 total time=   1.8s
# [CV 4/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.658 total time=   1.5s
# [CV 5/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.677 total time=   1.4s
# [CV 1/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.636 total time=   1.3s
# [CV 2/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.663 total time=   1.5s
# [CV 3/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.646 total time=   1.4s
# [CV 4/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.632 total time=   1.3s
# [CV 5/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.653 total time=   1.5s
# [CV 1/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.617 total time=   1.3s
# [CV 2/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.630 total time=   1.3s
# [CV 3/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.622 total time=   1.4s
# [CV 4/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.604 total time=   1.8s
# [CV 5/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.642 total time=   1.4s
# [CV 1/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.599 total time=   1.5s
# [CV 2/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.624 total time=   1.4s
# [CV 3/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.600 total time=   1.4s
# [CV 4/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.610 total time=   1.5s
# [CV 5/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.630 total time=   1.6s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.645 total time=   1.5s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.681 total time=   1.4s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.652 total time=   1.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.653 total time=   1.6s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.668 total time=   1.5s
# [CV 1/5] END .........C=10, gamma=2, kernel=rbf;, score=0.635 total time=   1.3s
# [CV 2/5] END .........C=10, gamma=2, kernel=rbf;, score=0.662 total time=   1.5s
# [CV 3/5] END .........C=10, gamma=2, kernel=rbf;, score=0.641 total time=   1.4s
# [CV 4/5] END .........C=10, gamma=2, kernel=rbf;, score=0.631 total time=   1.4s
# [CV 5/5] END .........C=10, gamma=2, kernel=rbf;, score=0.653 total time=   1.4s
# [CV 1/5] END .........C=10, gamma=3, kernel=rbf;, score=0.614 total time=   1.4s
# [CV 2/5] END .........C=10, gamma=3, kernel=rbf;, score=0.628 total time=   1.4s
# [CV 3/5] END .........C=10, gamma=3, kernel=rbf;, score=0.623 total time=   1.5s
# [CV 4/5] END .........C=10, gamma=3, kernel=rbf;, score=0.605 total time=   1.4s
# [CV 5/5] END .........C=10, gamma=3, kernel=rbf;, score=0.641 total time=   1.4s
# [CV 1/5] END .........C=10, gamma=4, kernel=rbf;, score=0.599 total time=   1.3s
# [CV 2/5] END .........C=10, gamma=4, kernel=rbf;, score=0.625 total time=   1.7s
# [CV 3/5] END .........C=10, gamma=4, kernel=rbf;, score=0.600 total time=   1.4s
# [CV 4/5] END .........C=10, gamma=4, kernel=rbf;, score=0.609 total time=   1.4s
# [CV 5/5] END .........C=10, gamma=4, kernel=rbf;, score=0.629 total time=   1.3s
# [CV 1/5] END .........C=15, gamma=1, kernel=rbf;, score=0.643 total time=   1.4s
# [CV 2/5] END .........C=15, gamma=1, kernel=rbf;, score=0.680 total time=   1.5s
# [CV 3/5] END .........C=15, gamma=1, kernel=rbf;, score=0.654 total time=   1.6s
# [CV 4/5] END .........C=15, gamma=1, kernel=rbf;, score=0.654 total time=   1.6s
# [CV 5/5] END .........C=15, gamma=1, kernel=rbf;, score=0.674 total time=   1.5s
# [CV 1/5] END .........C=15, gamma=2, kernel=rbf;, score=0.634 total time=   1.3s
# [CV 2/5] END .........C=15, gamma=2, kernel=rbf;, score=0.662 total time=   1.5s
# [CV 3/5] END .........C=15, gamma=2, kernel=rbf;, score=0.641 total time=   1.3s
# [CV 4/5] END .........C=15, gamma=2, kernel=rbf;, score=0.631 total time=   1.4s
# [CV 5/5] END .........C=15, gamma=2, kernel=rbf;, score=0.650 total time=   1.5s
# [CV 1/5] END .........C=15, gamma=3, kernel=rbf;, score=0.615 total time=   1.3s
# [CV 2/5] END .........C=15, gamma=3, kernel=rbf;, score=0.628 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=3, kernel=rbf;, score=0.623 total time=   1.4s
# [CV 4/5] END .........C=15, gamma=3, kernel=rbf;, score=0.605 total time=   1.4s
# [CV 5/5] END .........C=15, gamma=3, kernel=rbf;, score=0.642 total time=   1.4s
# [CV 1/5] END .........C=15, gamma=4, kernel=rbf;, score=0.599 total time=   1.3s
# [CV 2/5] END .........C=15, gamma=4, kernel=rbf;, score=0.625 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=4, kernel=rbf;, score=0.600 total time=   1.3s
# [CV 4/5] END .........C=15, gamma=4, kernel=rbf;, score=0.609 total time=   1.4s
# [CV 5/5] END .........C=15, gamma=4, kernel=rbf;, score=0.629 total time=   1.4s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [5, 10, 15], 'gamma': [1, 2, 3, 4],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid_svc_scaled.best_params_)
print(grid_svc_scaled.best_score_)
# Out:
# {'C': 5, 'gamma': 1, 'kernel': 'rbf'}
# 0.6611258884852315

# %% [markdown]
# #### Model Fit

# %%
C = grid_svc_scaled.best_params_['C'] 
gamma = grid_svc_scaled.best_params_['gamma']
kernel = grid_svc_scaled.best_params_['kernel']
                              
svc_scaled = SVC(C = C,
         gamma = gamma,
         kernel = kernel)

svc_scaled.fit(X_train_scaled,y_train)
# Out:
# SVC(C=5, gamma=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = svc_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.60      0.64       308
#            1       0.71      0.73      0.72       583
#            2       0.67      0.69      0.68       734
#
#     accuracy                           0.69      1625
#    macro avg       0.69      0.67      0.68      1625
# weighted avg       0.69      0.69      0.69      1625

# %% [markdown]
# ---

# %% [markdown]
# #### DecisionTreeClassifier

# %%
param_grid_dtc_scaled = { 
                  'criterion': ['gini', 'entropy', 'log_loss'], 
                  'splitter': ['best','random'],
                  'max_features': ['sqrt', 'log2'],
                  'max_depth': [10,20, 30], 
                  'max_leaf_nodes': [900,1000,1100],
                  'min_samples_split': [4,6,8], 
                    } 

grid_dtc_scaled = GridSearchCV(
                        DecisionTreeClassifier(),
                        param_grid_dtc_scaled,
                        refit=True,verbose=3
                       )

grid_dtc_scaled.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.556 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.603 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.592 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.582 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.509 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.559 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.523 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.547 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.531 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.593 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.628 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.608 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.589 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.559 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.498 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.577 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.509 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.541 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.569 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.600 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.606 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.587 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.603 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.576 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.488 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.532 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.525 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.537 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.496 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.585 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.634 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.586 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.604 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.523 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.564 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.543 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.517 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.505 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.618 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.563 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.586 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.585 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.515 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.535 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.552 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.547 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.525 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.609 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.599 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.575 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.569 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.566 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.542 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.511 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.546 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.498 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.538 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.583 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.595 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.607 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.553 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.482 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.575 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.533 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.511 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.541 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.593 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.602 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.585 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.588 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.542 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.565 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.563 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.520 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.541 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.560 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.590 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.597 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.578 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.530 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.534 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.539 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.511 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.490 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.598 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.615 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.578 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.531 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.535 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.529 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.526 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.537 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.584 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.600 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.601 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.583 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.582 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.532 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.556 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.557 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.524 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.561 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.584 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.603 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.592 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.560 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.526 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.548 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.533 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.526 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.478 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.572 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.594 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.611 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.578 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.566 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.435 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.537 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.523 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.506 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.556 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.561 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.611 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.555 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.579 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.574 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.512 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.554 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.532 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.536 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.562 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.567 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.600 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.589 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.586 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.535 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.565 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.526 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.528 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.535 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.576 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.614 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.611 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.521 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.555 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.551 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.492 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.518 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.600 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.607 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.572 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.583 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.533 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.543 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.524 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.510 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.515 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.593 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.585 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.589 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.555 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.569 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.516 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.583 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.536 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.532 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.579 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.579 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.632 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.585 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.616 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.569 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.575 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.530 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.561 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.593 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.599 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.598 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.600 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.551 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.598 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.623 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.577 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.587 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.578 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.615 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.599 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.595 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.611 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.554 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.578 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.535 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.537 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.601 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.615 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.614 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.592 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.608 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.565 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.610 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.581 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.546 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.585 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.585 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.602 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.614 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.601 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.591 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.572 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.593 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.584 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.569 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.565 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.602 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.617 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.600 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.595 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.541 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.541 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.565 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.553 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.534 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.608 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.623 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.615 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.582 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.607 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.565 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.593 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.578 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.595 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.575 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.571 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.622 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.604 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.603 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.611 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.562 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.588 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.554 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.599 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.573 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.597 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.613 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.576 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.578 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.550 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.576 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.552 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.588 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.553 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.581 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.613 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.610 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.603 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.606 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.568 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.560 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.591 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.560 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.582 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.609 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.610 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.581 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.619 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.529 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.572 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.601 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.571 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.575 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.592 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.611 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.564 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.592 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.607 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.556 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.600 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.535 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.553 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.543 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.590 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.637 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.598 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.584 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.599 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.617 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.571 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.576 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.575 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.597 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.594 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.602 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.614 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.615 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.614 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=20, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.555 total time=   0.0s
# ...
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.597 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.601 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.562 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.601 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.534 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.568 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.574 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.547 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.606 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.623 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.601 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.600 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0.616 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.569 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.605 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.555 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.559 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=4, splitter=random;, score=0.539 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.599 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.616 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.604 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.601 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=best;, score=0.592 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.563 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.593 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.591 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.568 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=6, splitter=random;, score=0.556 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.597 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.615 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.604 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.604 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=best;, score=0.592 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.561 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.573 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.564 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.552 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=900, min_samples_split=8, splitter=random;, score=0.569 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.607 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.617 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.608 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.604 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=best;, score=0.594 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.564 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.582 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.582 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.574 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=4, splitter=random;, score=0.580 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.575 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.616 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.610 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.586 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=best;, score=0.618 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.584 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.582 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.539 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=6, splitter=random;, score=0.563 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.576 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.618 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.610 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=best;, score=0.568 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.557 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.563 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.589 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.532 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1000, min_samples_split=8, splitter=random;, score=0.567 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.595 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.594 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.606 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.613 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.627 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.572 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.596 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.585 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.564 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.591 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.577 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.607 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.595 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.597 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.602 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.576 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.592 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.579 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.588 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.568 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.598 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.608 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.600 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.579 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.594 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.555 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.578 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.540 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.525 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.562 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [900, 1000, 1100],
#                          'min_samples_split': [4, 6, 8],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid_dtc_scaled.best_params_)
print(grid_dtc_scaled.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'max_leaf_nodes': 1100, 'min_samples_split': 4, 'splitter': 'best'}
# 0.6227374295793188

# %% [markdown]
# #### Model Fit

# %%
dtc_scaled = DecisionTreeClassifier( 
                             criterion =grid_dtc_scaled.best_params_['criterion'],
                             splitter = grid_dtc_scaled.best_params_['splitter'],
                             max_features =  grid_dtc_scaled.best_params_['max_features'],
                             max_depth =  grid_dtc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_scaled.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_scaled.best_params_['min_samples_split']
    
                            )

dtc_scaled.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        max_leaf_nodes=1100, min_samples_split=4)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = dtc_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.59       308
#            1       0.65      0.68      0.66       583
#            2       0.64      0.58      0.61       734
#
#     accuracy                           0.62      1625
#    macro avg       0.61      0.63      0.62      1625
# weighted avg       0.63      0.62      0.62      1625

# %% [markdown]
# ---

# %% [markdown]
# #### RandomForestClassifier

# %%
param_grid_rfc_scaled = { 
                 'n_estimators': [200, 215,220], 
                 'max_features': ['sqrt', 'log2', None], 
                 'max_depth': [10,20, 30], 
                 'max_leaf_nodes': [900,1000,1100],
                 'min_samples_split': [4,6,8], 
                 } 

grid_rfc_scaled = GridSearchCV(
                        RandomForestClassifier(),
                        param_grid_rfc_scaled,
                        refit=True,verbose=3
                       )

grid_rfc_scaled.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.641 total time=   1.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.703 total time=   1.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.664 total time=   1.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.665 total time=   1.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.662 total time=   2.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.651 total time=   1.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.687 total time=   2.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.671 total time=   2.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.667 total time=   2.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.663 total time=   2.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.642 total time=   2.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.691 total time=   2.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0
total time=   5.9s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.677 total time=   5.5s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.705 total time=   5.2s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.721 total time=   5.2s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.682 total time=   5.2s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.688 total time=   5.3s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.677 total time=   5.7s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.716 total time=   5.6s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.716 total time=   5.6s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.680 total time=   5.6s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.692 total time=   5.5s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.672 total time=   5.8s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.708 total time=   6.2s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.707 total time=   6.4s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.684 total time=   6.3s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.684 total time=   6.2s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.682 total time=   6.1s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.698 total time=   6.4s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.711 total time=   5.7s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.674 total time=   5.7s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.684 total time=   6.0s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.680 total time=   5.9s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.705 total time=   6.2s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.709 total time=   6.1s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.681 total time=   6.1s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.692 total time=   5.9s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.672 total time=   6.1s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.706 total time=   6.1s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.708 total time=   6.1s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.691 total time=   6.0s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.690 total time=   6.2s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [900, 1000, 1100],
#                          'min_samples_split': [4, 6, 8],
#                          'n_estimators': [200, 215, 220]},
#              verbose=3)

# %%
print(grid_rfc_scaled.best_params_)
print(grid_rfc_scaled.best_score_)
# Out:
# {'max_depth': 20, 'max_features': 'sqrt', 'max_leaf_nodes': 900, 'min_samples_split': 4, 'n_estimators': 215}
# 0.7075118201442637

# %% [markdown]
# #### Model Fit

# %%
rfc_scaled = RandomForestClassifier( 
                             n_estimators = grid_rfc_scaled.best_params_['n_estimators'], 
                             max_features =  grid_rfc_scaled.best_params_['max_features'],
                             max_depth =  grid_rfc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_scaled.best_params_['max_leaf_nodes'],
    
                            )

rfc_scaled.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier(max_depth=20, max_leaf_nodes=900, n_estimators=215)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = rfc_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.57      0.65       308
#            1       0.75      0.78      0.77       583
#            2       0.68      0.73      0.71       734
#
#     accuracy                           0.72      1625
#    macro avg       0.73      0.69      0.71      1625
# weighted avg       0.72      0.72      0.72      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier (estimator = DecisionTreeClassifier)

# %%
param_grid_abc_dt_scaled = { 
                     'n_estimators': [210,212,215,],
                     'learning_rate':[0.5,0.75,1]
                    }

dtc_scaled = DecisionTreeClassifier( 
                             criterion =grid_dtc_scaled.best_params_['criterion'],
                             splitter = grid_dtc_scaled.best_params_['splitter'],
                             max_features =  grid_dtc_scaled.best_params_['max_features'],
                             max_depth =  grid_dtc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_scaled.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_scaled.best_params_['min_samples_split']
    
                            )


abc_dt_scaled = AdaBoostClassifier(estimator = dtc_scaled)

grid_abc_dt_scaled= GridSearchCV(
                          abc_dt_scaled,
                          param_grid_abc_dt,
                          refit=True,verbose=3
                          )

grid_abc_dt_scaled.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.672 total time=   4.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.709 total time=   4.3s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.698 total time=   4.2s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.692 total time=   4.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.700 total time=   4.4s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.670 total time=   4.3s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.719 total time=   4.2s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.698 total time=   4.4s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.701 total time=   4.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.702 total time=   4.5s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.672 total time=   4.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.714 total time=   4.1s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.716 total time=   4.4s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.692 total time=   4.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.699 total time=   4.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.681 total time=   4.4s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.710 total time=   4.5s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.715 total time=   4.1s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.698 total time=   4.3s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.705 total time=   4.3s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.679 total time=   4.2s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.719 total time=   5.0s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.705 total time=   5.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.696 total time=   8.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.691 total time=   6.9s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.674 total time=   6.2s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.723 total time=   5.8s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.714 total time=   6.1s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.704 total time=   5.3s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.691 total time=   4.7s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.674 total time=   4.4s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.715 total time=   4.4s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.701 total time=   4.6s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.695 total time=   5.2s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.698 total time=   5.3s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.670 total time=   5.4s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.719 total time=   4.6s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.718 total time=   4.7s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.703 total time=   5.1s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.704 total time=   4.5s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.679 total time=   4.4s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.721 total time=   4.3s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.713 total time=   4.3s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.705 total time=   4.3s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.693 total time=   4.5s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                                            max_depth=20,
#                                                                            max_features='sqrt',
#                                                                            max_leaf_nodes=1100,
#                                                                            min_samples_split=4)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_dt_scaled.best_params_)
print(grid_abc_dt_scaled.best_score_)
# Out:
# {'learning_rate': 1, 'n_estimators': 212}
# 0.7027949244458485

# %% [markdown]
# #### Model Fit

# %%
dtc_scaled = DecisionTreeClassifier( 
                             criterion =grid_dtc_scaled.best_params_['criterion'],
                             splitter = grid_dtc_scaled.best_params_['splitter'],
                             max_features =  grid_dtc_scaled.best_params_['max_features'],
                             max_depth =  grid_dtc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_scaled.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_scaled.best_params_['min_samples_split']
    
                            )

abc_dt_scaled = AdaBoostClassifier(
                        estimator = dtc_scaled,
                        n_estimators = grid_abc_dt_scaled.best_params_['n_estimators'],
                        learning_rate= grid_abc_dt_scaled.best_params_['learning_rate']
                        )

abc_dt_scaled.fit(X_train_scaled,y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                     max_depth=20,
#                                                     max_features='sqrt',
#                                                     max_leaf_nodes=1100,
#                                                     min_samples_split=4),
#                    learning_rate=1, n_estimators=212)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred= abc_dt_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.55      0.64       308
#            1       0.78      0.75      0.77       583
#            2       0.68      0.78      0.73       734
#
#     accuracy                           0.73      1625
#    macro avg       0.75      0.69      0.71      1625
# weighted avg       0.73      0.73      0.72      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier (estimator = RandomForestClassifier)

# %%
param_grid_abc_rfc_scaled = { 
                      'n_estimators': [210,212,215,],
                      'learning_rate':[0.5,0.75,1]
                     }

rfc_scaled = RandomForestClassifier( 
                             n_estimators = grid_rfc_scaled.best_params_['n_estimators'], 
                             max_features =  grid_rfc_scaled.best_params_['max_features'],
                             max_depth =  grid_rfc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_scaled.best_params_['max_leaf_nodes'],
                             
                            )

abc_rfc_scaled = AdaBoostClassifier(estimator = rfc)

grid_abc_rfc_scaled = GridSearchCV(
                           abc_rfc_scaled,
                           param_grid_abc_rfc_scaled,
                           refit=True,verbose=3
                           )

grid_abc_rfc_scaled.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.679 total time=   2.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.720 total time=   2.3s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.715 total time=   2.2s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.699 total time=   2.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.703 total time=   2.4s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.680 total time=   2.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.718 total time=   2.3s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.717 total time=   2.4s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.700 total time=   2.5s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.695 total time=   2.3s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.682 total time=   2.2s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.727 total time=   2.3s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.713 total time=   2.3s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.694 total time=   2.2s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.704 total time=   2.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.677 total time=   2.3s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.727 total time=   2.2s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.716 total time=   2.3s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.699 total time=   2.1s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.699 total time=   2.5s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.676 total time=   2.4s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.715 total time=   2.9s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.708 total time=   2.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.703 total time=   2.3s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.697 total time=   2.3s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.683 total time=   2.1s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.727 total time=   2.1s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.716 total time=   2.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.697 total time=   2.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.698 total time=   2.0s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.683 total time=   1.9s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.729 total time=   2.1s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.715 total time=   2.0s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.691 total time=   2.1s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.704 total time=   2.0s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.678 total time=   2.2s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.720 total time=   2.0s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.706 total time=   2.1s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.697 total time=   2.9s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.692 total time=   3.3s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.691 total time=   2.2s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.718 total time=   2.7s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.711 total time=   2.6s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.702 total time=   2.1s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.703 total time=   2.2s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=RandomForestClassifier(max_depth=30,
#                                                                            max_features='log2',
#                                                                            max_leaf_nodes=1000,
#                                                                            n_estimators=200)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_rfc_scaled.best_params_)
print(grid_abc_rfc_scaled.best_score_)
# Out:
# {'learning_rate': 1, 'n_estimators': 215}
# 0.7052547780761332

# %% [markdown]
# ### Mode Fit

# %%
rfc_scaled = RandomForestClassifier( 
                             n_estimators = grid_rfc_scaled.best_params_['n_estimators'], 
                             max_features =  grid_rfc_scaled.best_params_['max_features'],
                             max_depth =  grid_rfc_scaled.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_scaled.best_params_['max_leaf_nodes'],
                             #class_weight=class_weight_dict
    
                            )

abc_rfc_scaled = AdaBoostClassifier(
                             estimator = rfc,
                             n_estimators = grid_abc_rfc_scaled.best_params_['n_estimators'],
                             learning_rate= grid_abc_rfc_scaled.best_params_['learning_rate']
                            )

abc_rfc_scaled.fit(X_train_scaled,y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(max_depth=30,
#                                                     max_features='log2',
#                                                     max_leaf_nodes=1000,
#                                                     n_estimators=200),
#                    learning_rate=1, n_estimators=215)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = abc_rfc_scaled.predict(X_test_scaled)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.58      0.66       308
#            1       0.75      0.77      0.76       583
#            2       0.69      0.74      0.71       734
#
#     accuracy                           0.72      1625
#    macro avg       0.73      0.70      0.71      1625
# weighted avg       0.72      0.72      0.72      1625

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### PCA Analysis

# %% [markdown]
# #### Scaling X

# %%
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Viz

# %%
pca = PCA()
pca.fit(X_scaled)

pca.explained_variance_ratio_.shape[0]
n= [*range(1,pca.explained_variance_ratio_.shape[0]+1)]
plt.bar(n,pca.explained_variance_ratio_)
plt.show()

# %% [markdown]
# #### PCA Viz

# %%
pca = PCA(n_components = 3)
X_pca = pca.fit_transform(X_scaled)

pca_1 = X_pca[:,0]
pca_2= X_pca[:,1]
pca_3 = X_pca[:,2]

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(pca_1, pca_2, pca_3, 'gray',c=y)
plt.show()

# %% [markdown]
# #### PCA Training & Testing Data

# %%
pca = PCA(n_components = 10)
X_pca_train = pca.fit_transform(X_train_scaled)
X_pca_test =  pca.transform(X_test_scaled)

# %% [markdown]
# ---

# %% [markdown]
# ### Models

# %% [markdown]
# ---

# %% [markdown]
# #### KNeighborsClassifier

# %%
train_scores_pca = []
test_scores_pca = []
for n in range(1,10):
    knc_pca = KNeighborsClassifier(n_neighbors = n)
    knc_pca.fit(
            X_pca_train,
            y_train
           )
    train_scores_pca.append(knc_pca.score(X_pca_train,y_train))
    test_scores_pca.append(knc_pca.score(X_pca_test,y_test))

# %%
plt.plot([*range(1,10)],train_scores_pca)
plt.plot([*range(1,10)],test_scores_pca)
plt.show()

# %% [markdown]
# #### Model Fit

# %%
knc_pca = KNeighborsClassifier(n_neighbors = 1 )
knc_pca.fit(X_pca_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = knc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64       308
#            1       0.68      0.70      0.69       583
#            2       0.67      0.63      0.65       734
#
#     accuracy                           0.66      1625
#    macro avg       0.66      0.67      0.66      1625
# weighted avg       0.66      0.66      0.66      1625

# %% [markdown]
# ---

# %% [markdown]
# #### SVC

# %%
param_grid_svc_pca = {
              'C': [5,10,15], 
              'gamma': [1,2,3,4],
              'kernel': ['rbf']
              }
grid_svc_pca= GridSearchCV(
                              SVC(),
                              param_grid_svc_pca,
                              refit=True,verbose=3
                             )

grid_svc_pca.fit(X_pca_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.638 total time=   1.4s
# [CV 2/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.686 total time=   1.4s
# [CV 3/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.653 total time=   1.4s
# [CV 4/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.658 total time=   1.5s
# [CV 5/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.677 total time=   1.4s
# [CV 1/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.635 total time=   1.3s
# [CV 2/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.665 total time=   1.2s
# [CV 3/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.645 total time=   1.5s
# [CV 4/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.636 total time=   1.6s
# [CV 5/5] END ..........C=5, gamma=2, kernel=rbf;, score=0.657 total time=   1.4s
# [CV 1/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.621 total time=   1.4s
# [CV 2/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.636 total time=   1.3s
# [CV 3/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.626 total time=   1.5s
# [CV 4/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.610 total time=   1.5s
# [CV 5/5] END ..........C=5, gamma=3, kernel=rbf;, score=0.642 total time=   1.4s
# [CV 1/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.598 total time=   1.4s
# [CV 2/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.623 total time=   1.3s
# [CV 3/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.600 total time=   1.2s
# [CV 4/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.607 total time=   1.3s
# [CV 5/5] END ..........C=5, gamma=4, kernel=rbf;, score=0.634 total time=   1.3s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.640 total time=   1.7s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.684 total time=   1.5s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.652 total time=   1.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.654 total time=   1.5s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.671 total time=   1.4s
# [CV 1/5] END .........C=10, gamma=2, kernel=rbf;, score=0.634 total time=   1.4s
# [CV 2/5] END .........C=10, gamma=2, kernel=rbf;, score=0.663 total time=   1.5s
# [CV 3/5] END .........C=10, gamma=2, kernel=rbf;, score=0.643 total time=   1.4s
# [CV 4/5] END .........C=10, gamma=2, kernel=rbf;, score=0.636 total time=   1.4s
# [CV 5/5] END .........C=10, gamma=2, kernel=rbf;, score=0.655 total time=   1.3s
# [CV 1/5] END .........C=10, gamma=3, kernel=rbf;, score=0.616 total time=   1.3s
# [CV 2/5] END .........C=10, gamma=3, kernel=rbf;, score=0.636 total time=   1.5s
# [CV 3/5] END .........C=10, gamma=3, kernel=rbf;, score=0.628 total time=   1.3s
# [CV 4/5] END .........C=10, gamma=3, kernel=rbf;, score=0.610 total time=   1.3s
# [CV 5/5] END .........C=10, gamma=3, kernel=rbf;, score=0.638 total time=   1.1s
# [CV 1/5] END .........C=10, gamma=4, kernel=rbf;, score=0.598 total time=   1.4s
# [CV 2/5] END .........C=10, gamma=4, kernel=rbf;, score=0.624 total time=   1.3s
# [CV 3/5] END .........C=10, gamma=4, kernel=rbf;, score=0.600 total time=   1.4s
# [CV 4/5] END .........C=10, gamma=4, kernel=rbf;, score=0.608 total time=   1.3s
# [CV 5/5] END .........C=10, gamma=4, kernel=rbf;, score=0.632 total time=   1.3s
# [CV 1/5] END .........C=15, gamma=1, kernel=rbf;, score=0.638 total time=   1.4s
# [CV 2/5] END .........C=15, gamma=1, kernel=rbf;, score=0.680 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=1, kernel=rbf;, score=0.655 total time=   1.5s
# [CV 4/5] END .........C=15, gamma=1, kernel=rbf;, score=0.656 total time=   1.4s
# [CV 5/5] END .........C=15, gamma=1, kernel=rbf;, score=0.676 total time=   1.4s
# [CV 1/5] END .........C=15, gamma=2, kernel=rbf;, score=0.633 total time=   1.4s
# [CV 2/5] END .........C=15, gamma=2, kernel=rbf;, score=0.663 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=2, kernel=rbf;, score=0.641 total time=   1.3s
# [CV 4/5] END .........C=15, gamma=2, kernel=rbf;, score=0.636 total time=   1.4s
# [CV 5/5] END .........C=15, gamma=2, kernel=rbf;, score=0.654 total time=   1.5s
# [CV 1/5] END .........C=15, gamma=3, kernel=rbf;, score=0.616 total time=   1.2s
# [CV 2/5] END .........C=15, gamma=3, kernel=rbf;, score=0.636 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=3, kernel=rbf;, score=0.628 total time=   1.3s
# [CV 4/5] END .........C=15, gamma=3, kernel=rbf;, score=0.610 total time=   1.3s
# [CV 5/5] END .........C=15, gamma=3, kernel=rbf;, score=0.638 total time=   1.3s
# [CV 1/5] END .........C=15, gamma=4, kernel=rbf;, score=0.598 total time=   1.4s
# [CV 2/5] END .........C=15, gamma=4, kernel=rbf;, score=0.624 total time=   1.4s
# [CV 3/5] END .........C=15, gamma=4, kernel=rbf;, score=0.600 total time=   1.3s
# [CV 4/5] END .........C=15, gamma=4, kernel=rbf;, score=0.608 total time=   1.3s
# [CV 5/5] END .........C=15, gamma=4, kernel=rbf;, score=0.632 total time=   1.4s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [5, 10, 15], 'gamma': [1, 2, 3, 4],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid_svc_pca.best_params_)
print(grid_svc_pca.best_score_)
# Out:
# {'C': 5, 'gamma': 1, 'kernel': 'rbf'}
# 0.662356447112094

# %% [markdown]
# #### Model Fit

# %%
C = grid_svc_pca.best_params_['C'] 
gamma = grid_svc_pca.best_params_['gamma']
kernel = grid_svc_pca.best_params_['kernel']
                              
svc_pca = SVC(C = C,
         gamma = gamma,
         kernel = kernel)

svc_pca.fit(X_pca_train,y_train)
# Out:
# SVC(C=5, gamma=1)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = svc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64       308
#            1       0.71      0.73      0.72       583
#            2       0.67      0.69      0.68       734
#
#     accuracy                           0.69      1625
#    macro avg       0.69      0.67      0.68      1625
# weighted avg       0.69      0.69      0.69      1625

# %% [markdown]
# ---

# %% [markdown]
# #### Class Weights

# %%
classes = np.unique(y)
weights = compute_class_weight(class_weight='balanced',
                                    classes=classes,
                                    y=y_train)
class_weight_dict = {clas: weight for clas, weight in zip(classes, weights)}

# %% [markdown]
# #### DecisionTreeClassifier

# %%
param_grid_dtc_pca = { 
                  'criterion': ['gini', 'entropy', 'log_loss'], 
                  'splitter': ['best','random'],
                  'max_features': ['sqrt', 'log2'],
                  'max_depth': [10,20, 30], 
                  'max_leaf_nodes': [900,1000,1100],
                  'min_samples_split': [4,6,8],
                    } 

grid_dtc_pca = GridSearchCV(
                        DecisionTreeClassifier(class_weight = class_weight_dict),
                        param_grid_dtc_pca,
                        refit=True,verbose=3,
                       )

grid_dtc_pca.fit(X_pca_train,y_train)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, splitter=best;, score=0
total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.587 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.639 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.582 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=best;, score=0.589 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.549 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.561 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.591 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=4, splitter=random;, score=0.563 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.574 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.593 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.605 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.566 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=best;, score=0.606 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.542 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.556 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.561 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.562 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=6, splitter=random;, score=0.543 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.588 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.591 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.569 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=best;, score=0.584 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.542 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.562 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.539 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.521 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=30, max_features=log2, max_leaf_nodes=1100, min_samples_split=8, splitter=random;, score=0.552 total time=   0.0s
# GridSearchCV(estimator=DecisionTreeClassifier(class_weight={0: 1.675954592363261,
#                                                             1: 0.9017212659633537,
#                                                             2: 0.7725975261655567}),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'max_leaf_nodes': [900, 1000, 1100],
#                          'min_samples_split': [4, 6, 8],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid_dtc_pca.best_params_)
print(grid_dtc_pca.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'max_leaf_nodes': 1000, 'min_samples_split': 4, 'splitter': 'best'}
# 0.6133015321434212

# %% [markdown]
# #### Model Fit

# %%
dtc_pca = DecisionTreeClassifier( 
                             criterion =grid_dtc_pca.best_params_['criterion'],
                             splitter = grid_dtc_pca.best_params_['splitter'],
                             max_features =  grid_dtc_pca.best_params_['max_features'],
                             max_depth =  grid_dtc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_pca.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_pca.best_params_['min_samples_split'],
                             class_weight = class_weight_dict
                            )

dtc_pca.fit(X_pca_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 1.675954592363261,
#                                      1: 0.9017212659633537,
#                                      2: 0.7725975261655567},
#                        max_depth=20, max_features='sqrt', max_leaf_nodes=1000,
#                        min_samples_split=4)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = dtc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.60      0.56       308
#            1       0.63      0.65      0.64       583
#            2       0.64      0.59      0.61       734
#
#     accuracy                           0.61      1625
#    macro avg       0.60      0.61      0.61      1625
# weighted avg       0.62      0.61      0.61      1625

# %% [markdown]
# ---

# %% [markdown]
# #### RandomForestClassifier

# %%
param_grid_rfc_pca = { 
                 'n_estimators': [200, 215,220], 
                 'max_features': ['sqrt', 'log2', None], 
                 'max_depth': [10,20, 30], 
                 'max_leaf_nodes': [900,1000,1100],
                 'min_samples_split': [4,6,8], 
                 } 

grid_rfc_pca = GridSearchCV(
                        RandomForestClassifier(class_weight = class_weight_dict),
                        param_grid_rfc_pca,
                        refit=True,verbose=3
                       )

grid_rfc_pca.fit(X_pca_train,y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.648 total time=   2.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.682 total time=   2.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.656 total time=   2.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.657 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=200;, score=0.687 total time=   3.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.651 total time=   3.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.685 total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.660 total time=   2.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.661 total time=   3.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=215;, score=0.680 total time=   3.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.657 total time=   3.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.697 total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.652 total time=   3.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.667 total time=   3.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=4, n_estimators=220;, score=0.668 total time=   3.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.652 total time=   2.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.687 total time=   3.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.649 total time=   3.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.660 total time=   2.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=200;, score=0.680 total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.643 total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.682 total time=   3.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.665 total time=   3.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.663 total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=215;, score=0.665 total time=   3.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.642 total time=   3.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.682 total time=   3.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.648 total time=   3.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.652 total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=6, n_estimators=220;, score=0.670 total time=   3.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.639 total time=   3.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.680 total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.648 total time=   2.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.663 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=200;, score=0.669 total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.641 total time=   2.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.681 total time=   3.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.647 total time=   3.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.651 total time=   3.3s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=215;, score=0.670 total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.634 total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.681 total time=   3.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.651 total time=   3.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.658 total time=   3.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=900, min_samples_split=8, n_estimators=220;, score=0.679 total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.646 total time=   2.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.683 total time=   3.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.665 total time=   3.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.663 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=200;, score=0.679 total time=   2.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.657 total time=   2.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.691 total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.655 total time=   3.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.654 total time=   3.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=215;, score=0.683 total time=   3.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.647 total time=   3.1s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.682 total time=   2.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.660 total time=   2.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.661 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=4, n_estimators=220;, score=0.676 total time=   2.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.645 total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.681 total time=   2.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.658 total time=   2.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.664 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=200;, score=0.674 total time=   2.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.644 total time=   3.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.685 total time=   3.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.659 total time=   3.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.658 total time=   3.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=215;, score=0.672 total time=   2.8s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.645 total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.681 total time=   3.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.648 total time=   3.3s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.653 total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=6, n_estimators=220;, score=0.678 total time=   3.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.640 total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.681 total time=   2.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.649 total time=   2.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.657 total time=   2.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=200;, score=0.679 total time=   2.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.637 total time=   2.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.676 total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.657 total time=   2.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.662 total time=   3.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=215;, score=0.678 total time=   3.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.637 total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.683 total time=   3.3s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.657 total time=   3.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.649 total time=   2.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1000, min_samples_split=8, n_estimators=220;, score=0.679 total time=   3.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.646 total time=   2.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.682 total time=   2.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.661 total time=   2.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.663 total time=   2.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=200;, score=0.680 total time=   2.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.650 total time=   2.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.692 total time=   2.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.658 total time=   3.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.669 total time=   2.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=215;, score=0.686 total time=   3.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.650 total time=   3.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.686 total time=   3.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0.660 total time=   2.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, max_leaf_nodes=1100, min_samples_split=4, n_estimators=220;, score=0
0s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.679 total time=   8.5s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.703 total time=   8.3s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.669 total time=   7.4s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.683 total time=   7.3s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=200;, score=0.721 total time=   8.5s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.669 total time=   8.7s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.698 total time=   8.9s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.670 total time=   8.3s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.675 total time=   7.9s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=215;, score=0.720 total time=   7.8s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.672 total time=   7.9s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.705 total time=   8.0s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.685 total time=   8.1s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.682 total time=   8.0s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=6, n_estimators=220;, score=0.716 total time=   9.0s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.670 total time=   8.2s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.708 total time=   8.1s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.672 total time=   7.8s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.679 total time=   8.2s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=200;, score=0.715 total time=   8.0s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.675 total time=   8.9s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.686 total time=   8.7s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.677 total time=   9.1s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.666 total time=   8.8s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=215;, score=0.715 total time=   8.2s
# [CV 1/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.678 total time=   8.3s
# [CV 2/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.698 total time=   8.6s
# [CV 3/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.670 total time=   8.9s
# [CV 4/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.671 total time=   8.5s
# [CV 5/5] END max_depth=30, max_features=None, max_leaf_nodes=1100, min_samples_split=8, n_estimators=220;, score=0.717 total time=   8.1s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [900, 1000, 1100],
#                          'min_samples_split': [4, 6, 8],
#                          'n_estimators': [200, 215, 220]},
#              verbose=3)

# %%
print(grid_rfc_pca.best_params_)
print(grid_rfc_pca.best_score_)
# Out:
# {'max_depth': 30, 'max_features': 'log2', 'max_leaf_nodes': 1100, 'min_samples_split': 6, 'n_estimators': 220}
# 0.69868625282999

# %% [markdown]
# #### Model Fit

# %%
rfc_pca = RandomForestClassifier( 
                             n_estimators = grid_rfc_pca.best_params_['n_estimators'], 
                             max_features =  grid_rfc_pca.best_params_['max_features'],
                             max_depth =  grid_rfc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_pca.best_params_['max_leaf_nodes'],
                             class_weight = class_weight_dict
                            )

rfc_pca.fit(X_pca_train,y_train)
# Out:
# RandomForestClassifier(class_weight={0: 1.675954592363261,
#                                      1: 0.9017212659633537,
#                                      2: 0.7725975261655567},
#                        max_depth=30, max_features='log2', max_leaf_nodes=1100,
#                        n_estimators=220)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = rfc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.62      0.69       308
#            1       0.76      0.76      0.76       583
#            2       0.69      0.75      0.72       734
#
#     accuracy                           0.73      1625
#    macro avg       0.74      0.71      0.72      1625
# weighted avg       0.73      0.73      0.73      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier(estimator = DecisionTreeClassifier )

# %%
param_grid_abc_dtc_pca = { 
                     'n_estimators': [210,212,215,],
                     'learning_rate':[0.5,0.75,1]
                    }

dtc_pca = DecisionTreeClassifier( 
                             criterion =grid_dtc_pca.best_params_['criterion'],
                             splitter = grid_dtc_pca.best_params_['splitter'],
                             max_features =  grid_dtc_pca.best_params_['max_features'],
                             max_depth =  grid_dtc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_pca.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_pca.best_params_['min_samples_split'],
                             class_weight = class_weight_dict
                            )


abc_dtc_pca = AdaBoostClassifier(estimator = dtc_pca)

grid_abc_dtc_pca= GridSearchCV(
                          abc_dtc_pca,
                          param_grid_abc_dtc_pca,
                          refit=True,verbose=3
                          )

grid_abc_dtc_pca.fit(X_pca_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.681 total time=   4.7s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.699 total time=   4.6s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.692 total time=   4.6s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.670 total time=   4.6s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.692 total time=   4.6s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.684 total time=   4.6s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.705 total time=   4.7s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.687 total time=   4.7s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.678 total time=   4.6s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.704 total time=   4.6s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.677 total time=   4.6s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.702 total time=   4.7s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.686 total time=   4.7s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.699 total time=   4.7s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.708 total time=   4.8s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.686 total time=   4.5s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.704 total time=   4.5s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.694 total time=   4.6s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.683 total time=   4.6s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.695 total time=   5.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.682 total time=   4.6s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.712 total time=   4.6s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.691 total time=   4.6s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.678 total time=   4.5s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.690 total time=   4.6s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.679 total time=   4.6s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.710 total time=   4.7s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.690 total time=   4.7s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.670 total time=   4.6s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.700 total time=   4.6s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.683 total time=   4.5s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.698 total time=   4.5s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.682 total time=   4.5s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.683 total time=   4.5s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.701 total time=   4.5s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.688 total time=   4.6s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.709 total time=   4.6s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.691 total time=   4.5s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.674 total time=   4.6s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.687 total time=   4.7s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.671 total time=   4.7s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.705 total time=   4.6s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.686 total time=   4.6s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.682 total time=   4.6s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.705 total time=   4.6s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(class_weight={0: 1.675954592363261,
#                                                                                          1: 0.9017212659633537,
#                                                                                          2: 0.7725975261655567},
#                                                                            max_depth=20,
#                                                                            max_features='sqrt',
#                                                                            max_leaf_nodes=1000,
#                                                                            min_samples_split=4)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_dtc_pca.best_params_)
print(grid_abc_dtc_pca.best_score_)
# Out:
# {'learning_rate': 0.5, 'n_estimators': 215}
# 0.6943781393144843

# %% [markdown]
# #### Model Fit

# %%
dtc_pca = DecisionTreeClassifier( 
                             criterion =grid_dtc_pca.best_params_['criterion'],
                             splitter = grid_dtc_pca.best_params_['splitter'],
                             max_features =  grid_dtc_pca.best_params_['max_features'],
                             max_depth =  grid_dtc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_dtc_pca.best_params_['max_leaf_nodes'],
                             min_samples_split = grid_dtc_pca.best_params_['min_samples_split'],
                             class_weight = class_weight_dict
                            )
abc_dtc_pca = AdaBoostClassifier(
                        estimator = dtc_pca,
                        n_estimators = grid_abc_dtc_pca.best_params_['n_estimators'],
                        learning_rate= grid_abc_dtc_pca.best_params_['learning_rate']
                        )

abc_dtc_pca.fit(X_pca_train,y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(class_weight={0: 1.675954592363261,
#                                                                   1: 0.9017212659633537,
#                                                                   2: 0.7725975261655567},
#                                                     max_depth=20,
#                                                     max_features='sqrt',
#                                                     max_leaf_nodes=1000,
#                                                     min_samples_split=4),
#                    learning_rate=0.5, n_estimators=215)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred =abc_dtc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classfication Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.52      0.63       308
#            1       0.77      0.73      0.75       583
#            2       0.66      0.79      0.72       734
#
#     accuracy                           0.72      1625
#    macro avg       0.75      0.68      0.70      1625
# weighted avg       0.73      0.72      0.71      1625

# %% [markdown]
# ---

# %% [markdown]
# #### AdaBoostClassifier(estimator = RandonForestClassifier )

# %%
param_grid_abc_rfc_pca = { 
                      'n_estimators': [210,212,215,],
                      'learning_rate':[0.5,0.75,1]
                     }

rfc_pca = RandomForestClassifier( 
                             n_estimators = grid_rfc_pca.best_params_['n_estimators'], 
                             max_features =  grid_rfc_pca.best_params_['max_features'],
                             max_depth =  grid_rfc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_pca.best_params_['max_leaf_nodes'],
                             class_weight = class_weight_dict
                            )

abc_rfc_pca = AdaBoostClassifier(estimator = rfc_pca)

grid_abc_rfc_pca = GridSearchCV(
                           abc_rfc_pca,
                           param_grid_abc_rfc_pca,
                           refit=True,verbose=3
                           )

grid_abc_rfc_pca.fit(X_pca_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.5, n_estimators=210;, score=0.681 total time=   3.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=210;, score=0.710 total time=   3.2s
# [CV 3/5] END learning_rate=0.5, n_estimators=210;, score=0.694 total time=   3.3s
# [CV 4/5] END learning_rate=0.5, n_estimators=210;, score=0.676 total time=   3.3s
# [CV 5/5] END learning_rate=0.5, n_estimators=210;, score=0.708 total time=   3.2s
# [CV 1/5] END learning_rate=0.5, n_estimators=212;, score=0.688 total time=   3.1s
# [CV 2/5] END learning_rate=0.5, n_estimators=212;, score=0.696 total time=   3.2s
# [CV 3/5] END learning_rate=0.5, n_estimators=212;, score=0.685 total time=   3.1s
# [CV 4/5] END learning_rate=0.5, n_estimators=212;, score=0.681 total time=   3.0s
# [CV 5/5] END learning_rate=0.5, n_estimators=212;, score=0.706 total time=   3.0s
# [CV 1/5] END learning_rate=0.5, n_estimators=215;, score=0.671 total time=   3.0s
# [CV 2/5] END learning_rate=0.5, n_estimators=215;, score=0.709 total time=   3.1s
# [CV 3/5] END learning_rate=0.5, n_estimators=215;, score=0.696 total time=   3.0s
# [CV 4/5] END learning_rate=0.5, n_estimators=215;, score=0.688 total time=   3.0s
# [CV 5/5] END learning_rate=0.5, n_estimators=215;, score=0.708 total time=   3.0s
# [CV 1/5] END learning_rate=0.75, n_estimators=210;, score=0.673 total time=   3.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=210;, score=0.713 total time=   3.0s
# [CV 3/5] END learning_rate=0.75, n_estimators=210;, score=0.690 total time=   3.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=210;, score=0.697 total time=   3.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=210;, score=0.717 total time=   3.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=212;, score=0.673 total time=   3.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=212;, score=0.711 total time=   3.0s
# [CV 3/5] END learning_rate=0.75, n_estimators=212;, score=0.690 total time=   3.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=212;, score=0.685 total time=   3.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=212;, score=0.701 total time=   3.1s
# [CV 1/5] END learning_rate=0.75, n_estimators=215;, score=0.669 total time=   3.0s
# [CV 2/5] END learning_rate=0.75, n_estimators=215;, score=0.714 total time=   3.0s
# [CV 3/5] END learning_rate=0.75, n_estimators=215;, score=0.679 total time=   3.0s
# [CV 4/5] END learning_rate=0.75, n_estimators=215;, score=0.689 total time=   3.0s
# [CV 5/5] END learning_rate=0.75, n_estimators=215;, score=0.711 total time=   3.0s
# [CV 1/5] END .learning_rate=1, n_estimators=210;, score=0.671 total time=   3.1s
# [CV 2/5] END .learning_rate=1, n_estimators=210;, score=0.718 total time=   3.2s
# [CV 3/5] END .learning_rate=1, n_estimators=210;, score=0.689 total time=   3.5s
# [CV 4/5] END .learning_rate=1, n_estimators=210;, score=0.690 total time=   3.4s
# [CV 5/5] END .learning_rate=1, n_estimators=210;, score=0.705 total time=   3.0s
# [CV 1/5] END .learning_rate=1, n_estimators=212;, score=0.668 total time=   3.3s
# [CV 2/5] END .learning_rate=1, n_estimators=212;, score=0.712 total time=   3.0s
# [CV 3/5] END .learning_rate=1, n_estimators=212;, score=0.690 total time=   3.2s
# [CV 4/5] END .learning_rate=1, n_estimators=212;, score=0.678 total time=   3.1s
# [CV 5/5] END .learning_rate=1, n_estimators=212;, score=0.706 total time=   3.0s
# [CV 1/5] END .learning_rate=1, n_estimators=215;, score=0.682 total time=   3.1s
# [CV 2/5] END .learning_rate=1, n_estimators=215;, score=0.705 total time=   3.5s
# [CV 3/5] END .learning_rate=1, n_estimators=215;, score=0.699 total time=   4.1s
# [CV 4/5] END .learning_rate=1, n_estimators=215;, score=0.684 total time=   3.3s
# [CV 5/5] END .learning_rate=1, n_estimators=215;, score=0.707 total time=   3.1s
# GridSearchCV(estimator=AdaBoostClassifier(estimator=RandomForestClassifier(class_weight={0: 1.675954592363261,
#                                                                                          1: 0.9017212659633537,
#                                                                                          2: 0.7725975261655567},
#                                                                            max_depth=30,
#                                                                            max_features='log2',
#                                                                            max_leaf_nodes=1100,
#                                                                            n_estimators=220)),
#              param_grid={'learning_rate': [0.5, 0.75, 1],
#                          'n_estimators': [210, 212, 215]},
#              verbose=3)

# %%
print(grid_abc_rfc_pca.best_params_)
print(grid_abc_rfc_pca.best_score_)
# Out:
# {'learning_rate': 0.75, 'n_estimators': 210}
# 0.6978674248407308

# %% [markdown]
# #### Model Fit

# %%
rfc_pca = RandomForestClassifier( 
                             n_estimators = grid_rfc_pca.best_params_['n_estimators'], 
                             max_features =  grid_rfc_pca.best_params_['max_features'],
                             max_depth =  grid_rfc_pca.best_params_['max_depth'], 
                             max_leaf_nodes = grid_rfc_pca.best_params_['max_leaf_nodes'],
                             class_weight = class_weight_dict
    
                            )

abc_rfc_pca = AdaBoostClassifier(
                             estimator = rfc_pca,
                             n_estimators = grid_abc_rfc_pca.best_params_['n_estimators'],
                             learning_rate= grid_abc_rfc_pca.best_params_['learning_rate']
                            )

abc_rfc_pca.fit(X_pca_train,y_train)
# Out:
# AdaBoostClassifier(estimator=RandomForestClassifier(class_weight={0: 1.675954592363261,
#                                                                   1: 0.9017212659633537,
#                                                                   2: 0.7725975261655567},
#                                                     max_depth=30,
#                                                     max_features='log2',
#                                                     max_leaf_nodes=1100,
#                                                     n_estimators=220),
#                    learning_rate=0.75, n_estimators=210)

# %% [markdown]
# #### Confusion Matrix

# %%
y_pred = abc_rfc_pca.predict(X_pca_test)

cm = confusion_matrix(y_test, y_pred)

display = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=le.classes_)
display.plot()
plt.show()

# %% [markdown]
# #### Classification Report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.60      0.67       308
#            1       0.75      0.75      0.75       583
#            2       0.68      0.73      0.70       734
#
#     accuracy                           0.71      1625
#    macro avg       0.73      0.69      0.71      1625
# weighted avg       0.72      0.71      0.71      1625
